# %%
import itertools

for i in itertools.groupby(sorted(map(lambda i: (random.randint(1, 10), i), xrange(1, 500))), lambda (k, v): k):
    print '%d:' % i[0], ' '.join(['%d' % n for k, n in i[1]])
# Out:
# 1: 7 15 39 45 55 56 66 81 84 94 104 112 119 124 135 152 169 174 184 191 198 202 214 218 224 254 267 268 274 282 287 298 304 316 321 329 340 345 347 349 353 355 377 381 386 390 438 446 448 453 458 468 471 478 489 495 497
# 2: 16 21 41 43 48 58 64 68 73 74 86 90 91 96 105 111 117 118 131 142 150 161 166 168 171 179 180 190 203 208 211 215 231 232 277 283 296 312 317 325 326 367 382 392 406 416 417 422 426 439 445 447 450 452 454 476 480 484 493
# 3: 4 17 18 22 27 30 31 47 50 51 59 61 75 76 78 82 97 101 120 122 126 141 143 144 147 153 155 181 182 189 197 199 209 213 219 222 225 229 242 251 252 253 259 284 286 288 291 308 309 318 335 348 352 365 370 371 372 373 376 383 393 415 428 433 440 441 460 461 464
# 4: 12 28 34 36 38 44 65 77 79 87 88 99 116 125 128 129 136 139 140 162 173 192 201 221 230 234 237 239 240 255 269 271 275 302 333 338 339 344 359 361 362 363 380 389 391 395 404 405 421 427 430 434 456 463 473 475 483 488 491 494 498
# ...
